# %% [markdown]
# Imports necessary for this notebook

# %%
import pandas as pd

# %% [markdown]
# Let's read the data and take a look

# %%
excel_path = '../data/MotorUniversal_2k_5kHz_SemNorm.xlsx'
df = pd.read_excel(excel_path)
df
# Out:
#      Estado  Corrente  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         0  0.717573    0.714725    0.704585    0.694305    0.687011
# 1         0  0.719402    0.717330    0.708022    0.698305    0.691041
# 2         0  0.723090    0.721113    0.711632    0.701274    0.692945
# 3         0  0.729627    0.726485    0.715613    0.704214    0.695404
# 4         0  0.714636    0.714388    0.706626    0.698127    0.691818
# ..      ...       ...         ...         ...         ...         ...
# 495       2  0.722422    0.720920    0.712699    0.704530    0.699261
# 496       2  0.726260    0.726227    0.725950    0.725444    0.724643
# 497       2  0.726733    0.724837    0.715531    0.705948    0.699105
# 498       2  0.747386    0.745534    0.735654    0.724924    0.716467
# 499       2  0.740270    0.738251    0.728985    0.719566    0.713096
#
#      Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 1991  \
# ...

# %% [markdown]
# Some columns are unnamed, so lets rename the columns

# %%
columns = ['state'] + [f"c_{i}" for i in range(1000)] + [f"t_{i}" for i in range(1000)]
df.columns = columns
df
# Out:
#      state       c_0       c_1       c_2       c_3       c_4       c_5  \
# 0        0  0.717573  0.714725  0.704585  0.694305  0.687011  0.683188
# 1        0  0.719402  0.717330  0.708022  0.698305  0.691041  0.686480
# 2        0  0.723090  0.721113  0.711632  0.701274  0.692945  0.687295
# 3        0  0.729627  0.726485  0.715613  0.704214  0.695404  0.689836
# 4        0  0.714636  0.714388  0.706626  0.698127  0.691818  0.688184
# ..     ...       ...       ...       ...       ...       ...       ...
# 495      2  0.722422  0.720920  0.712699  0.704530  0.699261  0.697420
# 496      2  0.726260  0.726227  0.725950  0.725444  0.724643  0.723600
# 497      2  0.726733  0.724837  0.715531  0.705948  0.699105  0.695240
# 498      2  0.747386  0.745534  0.735654  0.724924  0.716467  0.710962
# 499      2  0.740270  0.738251  0.728985  0.719566  0.713096  0.710130
#
#           c_6       c_7       c_8  ...      t_990      t_991      t_992  \
# ...

# %% [markdown]
# Finally, let's save the dataset as csv, and put a unique identifier in the file name

# %%
output_path = '../data/dataset_20221127.csv'
df.to_csv(output_path, index=False)
